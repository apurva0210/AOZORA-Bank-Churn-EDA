# %% [markdown]
# # Exploring AOZORA Bank Churn Data

# %% [markdown]
# # 3 Levels for Data Exploration
#
# * Level 0 : Understanding Data
# * Level 1 : Univariate Analysis
# * Level 2 : Bi-Variate Analysis
# * Lever 3 : Multivariate Analysis and asking questions from data

# %% [markdown]
# ## Level 0 Tasks : Understanding Data
#
# 1.Visually inspect the first few and last few rows of the data \
# 2.Check the shape of the data frame \
# 3.Check the count of null values in each column \
# 4.Inspect all the column names and cross check with the data dictionary \
# 5.Check the information of the data frame using the info() function

# %% [markdown]
# ### Importing the necessary libraries

# %%
import matplotlib.pyplot as plt             # to visualize
from tabulate import tabulate               # to print the table
import matplotlib as mat                    # to visualize 
import seaborn as sns                       # to visualize
import pandas as pd                         # for data reading
import numpy as np                          # for numerical computation
import warnings
warnings.filterwarnings('ignore')

# %%
# Checking the library versions 
print("Pandas version: ",pd.__version__)
print("Seaborn version: ",sns.__version__)
print("Matplotlib version: ",mat.__version__)
# Out:
# Pandas version:  1.4.4
# Seaborn version:  0.11.2
# Matplotlib version:  3.5.2

# %% [markdown]
# ### Reading the file

# %%
# Ensure that the data file is in the current working directory as that of the jupyter notebook
df = pd.read_csv("DS1_C6_S1_BankChurn_Data_Concept.csv") # read_csv: inbuilt function of pandas to read files

# %% [markdown]
# # Level 0 Analysis : Understanding Data

# %% [markdown]
# ## Reading the top 5 rows

# %%
df.head() # head prints the top 5 rows
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %% [markdown]
# ## Reading the bottom 5 rows

# %%
df.tail() # tail returns the bottom 5 rows
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# ...

# %% [markdown]
# ##  Number of rows and columns

# %%
print(df.shape) #returns a tuple with the details number of rows and columns
# Out:
# (10127, 19)

# %% [markdown]
# ## Display the names of all the columns

# %%
print(df.columns) # returns array of columns in dataset
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Trans_Amt', 'Total_Trans_Ct',
#        'Avg_Utilization_Ratio'],
#       dtype='object')

# %% [markdown]
# ## Displaying the dataset information

# %%
df.info()       # returns the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10034 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             9995 non-null   object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %% [markdown]
# ## Checking if there are null values in any columns

# %%
df.isnull().sum()       # isnull returns the True/False dataframe
                            #sum: counts the number of True in columns
# Out:
# CLIENTNUM                     0
# Attrition_Flag                0
# Customer_Age                  0
# Gender                       93
# Dependent_count               0
# Education_Level               0
# Marital_Status                0
# Income_Category               0
# Card_Category               132
# Months_on_book                0
# Total_Relationship_Count      0
# Months_Inactive_12_mon        0
# Contacts_Count_12_mon         0
# Credit_Limit                 60
# Total_Revolving_Bal           0
# Avg_Open_To_Buy               0
# Total_Trans_Amt               0
# Total_Trans_Ct                0
# Avg_Utilization_Ratio         0
# dtype: int64

# %% [markdown]
# LEVEL 1 Analysis
# -------------------------
# Identify if the type data in each column is categorical or numerical?
# 1. Separate out the categorical columns from the numerical types
#
# ### These are the kind of analyses that can be performed on categorical data
# 1. Check if it is Nominal or Ordinal
# 2. Check how many categories are present
# 3. Check the Mode
# 4. Check for Missing values
# 5. Think about how the missing values could be treated
# 6. Think about the kind of graph/chart that can be plotted using this data
#
# Note: We are analyzing only one column at a time (Univariate Analysis).

# %% [markdown]
# ## Separating Categorical and Numerical Variables

# %%
# Seprating out the categorical and continuous variables
def seprate_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:                # looping on the number of columns
        if df[column].nunique() < 100:       # nunique:  returns unique values in the column,
                                                    #here 100 is the hyperparamter and can be changed
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous 


categorical, continuous = seprate_data_types(df)         # Calling the function

# # Tabulate is a package used to print the list, dict or any data sets in a proper format; in table format
from tabulate import tabulate
table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical               continuous
# ------------------------  ---------------------
# Attrition_Flag            CLIENTNUM
# Gender                    Customer_Age
# Dependent_count           Credit_Limit
# Education_Level           Total_Revolving_Bal
# Marital_Status            Avg_Open_To_Buy
# Income_Category           Total_Trans_Amt
# Card_Category             Total_Trans_Ct
# Months_on_book            Avg_Utilization_Ratio
# Total_Relationship_Count
# Months_Inactive_12_mon
# Contacts_Count_12_mon

# %% [markdown]
# # $$\;\;\;\; Univariate \ Analysis \ of \ Categorical \ Variables$$

# %% [markdown]
# ## Level 1 Analysis (Univariate Analysis)

# %% [markdown]
# ### User defined function for level 1 analysis of categorical columns
# This function will check for the following \
# Unique values \
# Mode \
# Total count of missing values

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") # unique: returns the unique values in the col
    print(f"Mode of {col} is {df[col].mode()[0]}")  # mode: returns the mode of the column
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}") # isnull().sum() counts the number of null in dataframe

# %% [markdown]
# ## 1. Analysis of Attrition Flag: If the account is closed, then Attired Customer else Existing Customer

# %%
info_of_cat("Attrition_Flag")
# Out:
# Unique values in Attrition_Flag are: ['Existing Customer' 'Attrited Customer']
# Mode of Attrition_Flag is Existing Customer
# Number of missing values in Attrition_Flag is 0

# %% [markdown]
# ###### Attrition Flag is a nominal datatype.

# %% [markdown]
# ### Visual presentation of Attrition Flag attribute

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Calculate the value counts of the "Attrition_Flag" column
data = df["Attrition_Flag"].value_counts()

# Get the unique categories (labels) in the "Attrition_Flag" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('Set2', n_colors=len(labels))

# Plot a count plot on the first subplot
sns.countplot(x='Attrition_Flag', data=df, order=labels, palette=colors, ax=axes[0])
axes[0].set_title("Attrition Flag Count")

# Plot a donut pie chart on the second subplot
wedges, texts, autotexts = axes[1].pie(data, labels=labels, colors=colors, autopct="%0.2f%%", startangle=30, wedgeprops=dict(width=0.4))
center_circle = plt.Circle((0, 0), 0.3, color='white')
axes[1].add_artist(center_circle)
axes[1].set_title("Attrition Flag Distribution")

# Set aspect ratio to be equal to ensure a circular shape in the pie chart
axes[1].axis('equal')

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.4)

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: The dataset indicates that 16% of the customers left the bank while 84% of the customers are still with it.

# %% [markdown]
# ## 2. Analysis of  Gender column: Gender of a person (Male or Female)

# %%
info_of_cat("Gender")
# Out:
# Unique values in Gender are: ['M' 'F' nan]
# Mode of Gender is F
# Number of missing values in Gender is 93

# %% [markdown]
# ###### Gender is a nominal datatype (Categorical).

# %% [markdown]
# ### Optional::Way to fill: Mode of the Gender Column
#
# Note: Mode is not the perfect way to fill the missing value in this case. One might need to handle such a situation with caution. This is for demonstration purposes only.

# %%
gender_mode = df.Gender.mode()[0]
print(gender_mode)
df["Gender"].fillna(gender_mode, inplace = True)
# Out:
# F

# %% [markdown]
# ### Visual presentation of Gender attribute

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Calculate the value counts of the "Gender" column
data = df["Gender"].value_counts()

# Get the unique categories (labels) in the "Gender" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('Set3', n_colors=len(labels))

# Plot a count plot on the first subplot
sns.countplot(x='Gender', data=df, order=labels, palette=colors, ax=axes[0])
axes[0].set_title("Gender Count")

# Plot a donut pie chart on the second subplot
wedges, texts, autotexts = axes[1].pie(data, labels=labels, colors=colors, autopct="%0.2f%%", startangle=30, wedgeprops=dict(width=0.4))
center_circle = plt.Circle((0, 0), 0.3, color='white')
axes[1].add_artist(center_circle)
axes[1].set_title("Gender Distribution")

# Set aspect ratio to be equal to ensure a circular shape in the pie chart
axes[1].axis('equal')

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.4)
plt.show()

# %% [markdown]
# ## ***Interpretation: Female customers are more in number, contributing to 53%.

# %% [markdown]
# ## 3. Analysis of  Dependent Count: Number of dependents on each customer

# %%
info_of_cat("Dependent_count") # check for the unique values in the feature
# Out:
# Unique values in Dependent_count are: [  3   5   4   2   0   1   9  29 103  22  25  78  90  35  60  42 119 104
#   88  48  34 143 100  59 130  95   7  82  69  92 110  17  10  27  19 109
#  142 116 113 125  80  63  24  97 102  52  87  11 117  13  67  89  61  72
#  120  76]
# Mode of Dependent_count is 3
# Number of missing values in Dependent_count is 0

# %% [markdown]
# ###### Dependent_count is an ordinal datatype (Categorical) as it has a hierarchy in it.

# %% [markdown]
# ## ***Interpretation: Some people are having many dependents on them. This could be a result of human error in data.
#
# Note: This might not always be the correct approach unless verified by a domain expert!

# %% [markdown]
# ### Visual presentation of Dependent_count attribute

# %%
fig, ax = plt.subplots(figsize= (20, 8))
ax = sns.countplot(x = df["Dependent_count"])
ax.set_title("Dependent Count")

for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height()*100 /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
    fig.set_figheight(10)                                                             # annotate: used to annotate over objects, here objects are the bars
    fig.set_figwidth(30)
plt.show()

# %% [markdown]
# ## ***Interpretation: Very few people are having more than 5 dependents. However, there are some cases where the dependent count is greater than 100, which is abnormal. Hence, data clearing might be  required.

# %% [markdown]
# ## Outliers Analysis and Treatment:
# The customers who have a Dependent Count greater than the 5 are replaced with the mean of the population.

# %%
# Making changes in data
mean = int(df.Dependent_count.mean())
# accessing the data higher than 5
x = df[df["Dependent_count"] > 5].index
for index in x:
    df.loc[index, "Dependent_count"] = mean

# %%
info_of_cat("Dependent_count")
# Out:
# Unique values in Dependent_count are: [3 5 4 2 0 1]
# Mode of Dependent_count is 3
# Number of missing values in Dependent_count is 0

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["Dependent_count"])
ax.set_title("Dependent Count")

for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height()*100 /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
                                                                    # annotate: used to annotate over objects, here objects are the bars
plt.show()

# %% [markdown]
# ## ***Interpretation: Cardholders usually have 2 to 3 dependents on them which add up to 53% of the total population.

# %% [markdown]
# ## 4. Analysis of  Education Level: Education level of a card holder

# %%
info_of_cat( "Education_Level")
# Out:
# Unique values in Education_Level are: ['High School' 'Graduate' 'Uneducated' 'Unknown' 'College' 'Post-Graduate'
#  'Doctorate']
# Mode of Education_Level is Graduate
# Number of missing values in Education_Level is 0

# %% [markdown]
# ###### Education_Level is an ordinal datatype (Categorical) as it is having a hierarchy in it.

# %% [markdown]
# ### Visual presentation of Education_level attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "Education_Level" column
data = df["Education_Level"].value_counts()

# Get the unique categories (labels) in the "Education_Level" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('hls', n_colors=len(labels))

# Plot a countplot on the first subplot
a=sns.countplot(x='Education_Level', data=df, order=labels, palette=colors, ax=ax[0])
a.set_xticklabels(a.get_xticklabels(), rotation = 40 , ha = "right")
a.set_title("Education Level Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode =[0.02,0.02, 0.02,0.03,0.07,0.1,0.3],pctdistance = 0.5 ,shadow=True, startangle=30)
plt.title("Education Level Distribution")
plt.show()

# %% [markdown]
# ## ***Interpretation: Most people are graduates or have completed high school, which adds up to 51% of the total population.

# %% [markdown]
# ## 5. Analysis of  Marital Status: Marital status of a card holder

# %%
info_of_cat("Marital_Status")
# Out:
# Unique values in Marital_Status are: ['Married' 'Single' 'Unknown' 'Divorced']
# Mode of Marital_Status is Married
# Number of missing values in Marital_Status is 0

# %% [markdown]
# ###### Marital_Status is a nominal datatype (Categorical).

# %% [markdown]
# ### Visual presentation of Marital_status attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "Marital_Status" column
data = df["Marital_Status"].value_counts()

# Get the unique categories (labels) in the "Marital_Status" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('Set3', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='Marital_Status', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Marital Status Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode=[0.02]*len(labels), shadow=True, startangle=60)
plt.title("Marital Statusl Distribution")
plt.show()

# %% [markdown]
# ## ***Interpretation:  46% of the people are Married and 39% are Single.

# %% [markdown]
# ## 6. Analysis of  Income Category: Income category of a card holder

# %%
info_of_cat( "Income_Category")
# Out:
# Unique values in Income_Category are: ['$60K - $80K' 'Less than $40K' '$80K - $120K' '$40K - $60K' '$120K +'
#  'Unknown']
# Mode of Income_Category is Less than $40K
# Number of missing values in Income_Category is 0

# %% [markdown]
# ###### Income_Category is an ordinal datatype (Categorical) as it is having a hierarchy in it.

# %% [markdown]
# ### Visual presentation of income category attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "Income_Category" column
data = df["Income_Category"].value_counts()

# Get the unique categories (labels) in the "Income_Category" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('husl', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='Income_Category', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Income Category Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode=[0.02]*len(labels), shadow=True, startangle=30)
plt.title("Income Category Distribution")
plt.show()

# %% [markdown]
# ## ***Interpretation:  The majority of the population is earning less than $40k.

# %% [markdown]
# ## 7. Analysis of  Card Category: Type of card

# %%
info_of_cat("Card_Category")
# Out:
# Unique values in Card_Category are: ['Blue' 'Gold' 'Silver' nan 'Platinum']
# Mode of Card_Category is Blue
# Number of missing values in Card_Category is 132

# %% [markdown]
# ###### Card_Category is a nominal datatype (Categorical).

# %% [markdown]
# ##    Missing value treatment:  Mode of the Card Type
#
# Note: Mode is not a perfect way to  way to fill the missing value in this case. One might need to handle such a situation with caution by consulting the domain expert. This is for demonstration purposes only.

# %%
card_mode = df.Card_Category.mode()[0]
print(card_mode)
df["Card_Category"].fillna(card_mode, inplace = True)
# Out:
# Blue

# %% [markdown]
# ### Visual presentation of card category attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "Card_Category" column
data = df["Card_Category"].value_counts()

# Get the unique categories (labels) in the "Card_Category" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('Set2', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='Card_Category', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Card Category Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode=[0.2, 0.2, 0.45, 0.67], shadow=True, startangle=10)
plt.title("Card Category Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: The majority of the population is using the Blue card followed by Silver. The Platinum card is sold the least.

# %% [markdown]
# ## 8. Analysis of Total Relationship Count: Years of relationship with bank

# %%
info_of_cat("Total_Relationship_Count")
# Out:
# Unique values in Total_Relationship_Count are: [5 6 4 3 2 1]
# Mode of Total_Relationship_Count is 3
# Number of missing values in Total_Relationship_Count is 0

# %% [markdown]
# ###### Total_Relationship_Count is a ordinal datatype (Categorical) as it is having hierarchy in it.

# %% [markdown]
# ### Visual presentation of Relationship count attribute

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["Total_Relationship_Count"])
ax.set_title("Total Relationship Count")

for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height()*100 /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
                                                                    # annotate: used to annotate over objects, here objects are the bars
plt.show()

# %% [markdown]
# ## ***Interpretation: Usually , people have three years of relationship with the bank. Then, there is a decline of 3%. Later, there is very little variation. Approximately 20% of people tend to leave in their first two years.

# %% [markdown]
# ## 9. Analysis of Months of Inactivity: Months elapsed since the last activity using a credit card.

# %%
info_of_cat('Months_Inactive_12_mon' )
# Out:
# Unique values in Months_Inactive_12_mon are: [1 4 2 3 6 0 5]
# Mode of Months_Inactive_12_mon is 3
# Number of missing values in Months_Inactive_12_mon is 0

# %% [markdown]
# ###### Total_Relationship_Count is an ordinal datatype (Categorical) as it is having hierarchy in it.

# %% [markdown]
# ### Visual presentation of month of inactivity attribute

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["Months_Inactive_12_mon"])
ax.set_title("Months Inactive 12 mon Count")

for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height()*100 /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
                                                                    # annotate: used to annotate over objects, here objects are the bars
plt.show()

# %% [markdown]
# ## ***Interpretation:  The majority of the customers are inactive for 3 months.

# %% [markdown]
# ## Here you will find more questions about the customers who have left the bank by relating the "attrition flag" column with every categorical column mentioned above.

# %% [markdown]
# 1. Genderwise count of customers who are with the bank and those who have left.
# 2. Is there a connection between the education level and the customers who have left the bank?
# 3. Marital Status analysis of those customers who have left the bank
# 4. Income category analysis of the customers who have left the bank
# 5. Card category analysis of the customers who have left the bank
# 6. Is there any relation between months inactive and churn?
# 7. Is there any relation between churn and relationship count?
# 8. Is there any relation between churn and contacts count?
# 9. Is there a relation between attrition and the age of customers who have a lower utilization ratio?
# 10. Analysis of marital status and utilization ratio of the customers who are leaving out the bank versus those who are still with the bank.
# 11. Is there a relation between the credit limit offered to the customers (having a lower utilization ratio) compared to those who are having a higher utilization ratio?
#
# Repeat the same analysis with the customers who are still with the bank.
#
# 1. Is there a connection between the education level and the existing customers?
# 2. Marital Status analysis of those customers who are with the bank
# 3. Income category analysis of customers who are with the bank
# 4. Card category analysis of the customers who are still with the bank
# 5. Is there any relation between months inactive and existing customers?
# 6. Is there any relation between existing customers and relationship count?
# 7. Is there any relation between existing customers and contacts count?

# %% [markdown]
# # $$\;\;\;\;\;\;Univariate \ Analysis \ of \ Numerical \ Variables$$

# %% [markdown]
# LEVEL 1 Analysis of Numerical Columns
# ----------------------------------------------------------
# Check if the data is discrete or continuous. \
# Measure the central tendency (mean, median, mode) \
# Measure the dispersion values \
# Check for missing values \
# Checking for skewness\
# Check for outliers \
# Think about how the missing values could be treated. \
# Think about the kind of graph/chart that can be plotted using this data.

# %% [markdown]
# ## User defined function for calculating mean, median, mode,  standard deviation, and count of all null values

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {df[col].mean()}")
    print(f"The median of the {col} is {df[col].median()}")
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {df[col].std()}")
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %% [markdown]
# ## 10. Analysis of  the Customer Age: Age of the customer

# %%
info_of_numerical("Customer_Age")
# Out:
# The mean of the Customer_Age is 47.285276982324476
# The median of the Customer_Age is 46.0
# The mode of the Customer_Age is 44
# The standard deviation of the Customer_Age is 13.270923260536502
# Number of missing values in the Customer_Age is 0

# %% [markdown]
# ###### Customer_Age is a continuous data  (Numerical).

# %% [markdown]
# ### Visual presentation of Customer Age Attribute

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plotting the histogram
sns.histplot(x=df["Customer_Age"], ax=ax[1], color="yellow")
ax[1].set_title("Customer Age Distribution")  

# Plotting the boxplot
sns.boxplot(x=df["Customer_Age"], ax=ax[0],color="brown")
ax[0].set_title("Customer Age Boxplot")  

plt.show()

# %% [markdown]
# In this case, the customer age follows the normal distribution. There are few customers with ages over 77. The analytics team decides to replace the ages greater than 75 with the average age of other customers.

# %% [markdown]
# ## Outliers Analysis and Treatment:

# %%
# Calculate the interquartile range (IQR)
Q1 = df['Customer_Age'].quantile(0.25)
Q3 = df['Customer_Age'].quantile(0.75)
IQR = Q3 - Q1

# Define the outlier threshold
outlier_threshold = 1.5

# Identify outliers using the IQR method
lower_bound = Q1 - outlier_threshold * IQR
upper_bound = Q3 + outlier_threshold * IQR
outliers = df[(df['Customer_Age'] < lower_bound) | (df['Customer_Age'] > upper_bound)]

# Calculate the mean of non-outlier data
median = df[(df['Customer_Age'] >= lower_bound) & (df['Customer_Age'] <= upper_bound)]['Customer_Age'].median()

# Replace outliers with the mean value
df.loc[df['Customer_Age'] < lower_bound, 'Customer_Age'] = median
df.loc[df['Customer_Age'] > upper_bound, 'Customer_Age'] = median

# %%
info_of_numerical("Customer_Age")
# Out:
# The mean of the Customer_Age is 46.312037128468454
# The median of the Customer_Age is 46.0
# The mode of the Customer_Age is 46
# The standard deviation of the Customer_Age is 7.964665961516242
# Number of missing values in the Customer_Age is 0

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plotting the histogram
sns.histplot(x=df["Customer_Age"], ax=ax[1], color="yellow")
ax[1].set_title("Customer Age Distribution")  

# Plotting the boxplot
sns.boxplot(x=df["Customer_Age"], ax=ax[0],color="brown")
ax[0].set_title("Customer Age Boxplot")  

plt.show()

# %% [markdown]
# ## ***Interpretation: Most likely, customer age follows the normal distribution. Most of the bank customers are in between 40 and 55 years of age.

# %% [markdown]
# ## 11. Analysis of  Total_Revolving_Bal: Balance that is carried over month to month

# %%
info_of_numerical("Total_Revolving_Bal")
# Out:
# The mean of the Total_Revolving_Bal is 1162.8140614199665
# The median of the Total_Revolving_Bal is 1276.0
# The mode of the Total_Revolving_Bal is 0
# The standard deviation of the Total_Revolving_Bal is 814.9873352357697
# Number of missing values in the Total_Revolving_Bal is 0

# %% [markdown]
# ###### Total_Revolving_Bal is a continuous datatype (Numerical).

# %% [markdown]
# ### Visual presentation of Total Revolving Balance Attribute

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plotting the histogram
sns.histplot(x=df["Total_Revolving_Bal"], ax=ax[1], color="m")
ax[1].set_title("Total Revolving Bal Distribution")  

# Plotting the boxplot
sns.boxplot(x=df["Total_Revolving_Bal"], ax=ax[0],color="g")
ax[0].set_title("Total_Revolving_Bal Boxplot")  

plt.show()

# %% [markdown]
# ## ***Interpretation: There is a spike at the 0 Revolving Balance, which indicates the majority of people tend to have a 0 Revolving Balance. Around 25% of the customers do not have a revolving balance, i.e. they settle the credit card bill within a month. Around 75% of customers do not pay their credit card balance on time. These are the profitable customers of the bank (they pay interest on the revolving balance).

# %% [markdown]
# ## 12. Analysis of  Avg_Open_To_Buy:
# ### Difference between the credit limit assigned to a cardholder and the present balance on the account at that time.
#
# ```Description: Monthly credit limit is $12,000.  If the customer spends $5,000 in a month, then the remaining balance is $7,000 which is called "Average Open to Buy".```

# %%
info_of_numerical("Avg_Open_To_Buy")
# Out:
# The mean of the Avg_Open_To_Buy is 7469.139636614887
# The median of the Avg_Open_To_Buy is 3474.0
# The mode of the Avg_Open_To_Buy is 1438.3
# The standard deviation of the Avg_Open_To_Buy is 9090.685323679128
# Number of missing values in the Avg_Open_To_Buy is 0

# %% [markdown]
# ###### Avg_Open_To_Buy is a continuous datatype (Numerical).

# %% [markdown]
# ### Visual presentation of Avg Open To Buy Attribute

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))
sns.histplot(df["Avg_Open_To_Buy"], ax = ax[1], color= "g")     # xaxis: its a dollar amount which shows the difference between the credit limit and the prersent balance
ax[1].set_title("Avg Open To Buy Distribution")  
sns.boxplot(x = df['Avg_Open_To_Buy'], ax = ax[0], color = "y") 
ax[0].set_title("Avg Open To Buy Boxplot")  
plt.show()

# %% [markdown]
# ### Outliers Analysis
# This is right skewed data but the strength of outliers is increasing at the end of the tail which indicates that outliers are not human errors but some people are showing behaviour other than population.

# %% [markdown]
# ## 13. Analysis of  the Total Transaction Count: Number of transactions made by the card holder

# %%
info_of_numerical("Total_Trans_Ct")
# Out:
# The mean of the Total_Trans_Ct is 64.85869457884863
# The median of the Total_Trans_Ct is 67.0
# The mode of the Total_Trans_Ct is 81
# The standard deviation of the Total_Trans_Ct is 23.472570449233046
# Number of missing values in the Total_Trans_Ct is 0

# %% [markdown]
# ###### Total_Trans_Ct is a continuous datatype (Numerical).

# %% [markdown]
# ### Visual presentation of Total transaction count Attribute

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))
sns.histplot(df["Total_Trans_Ct"], ax = ax[1], color= "orange")     
ax[1].set_title("Total Transaction Count Distribution")  
sns.boxplot(x = df['Total_Trans_Ct'], ax = ax[0])
ax[0].set_title("Total Transaction Count Boxplot")  
plt.show()

# %% [markdown]
# ## ***Interpretation: The majority of the customers are making more than 50 transactions.

# %% [markdown]
# ## 14. Analysis of  the Avg_Utilization_Ratio: It is a ratio of Total Revolving Balance to Credit Limit
# #### $$\frac{Total\;Revolving\; Balance}{Credit \;Limit}$$
# ### The higher the value, the more the customers are spending

# %%
info_of_numerical("Avg_Utilization_Ratio")
# Out:
# The mean of the Avg_Utilization_Ratio is 0.2748935518909845
# The median of the Avg_Utilization_Ratio is 0.176
# The mode of the Avg_Utilization_Ratio is 0.0
# The standard deviation of the Avg_Utilization_Ratio is 0.2756914692523933
# Number of missing values in the Avg_Utilization_Ratio is 0

# %% [markdown]
# ###### Avg_Utilization_Ratio is a continuous datatype (Numerical).

# %% [markdown]
# ### Visual presentation of Avg utilization ration Attribute

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))
sns.histplot(df["Avg_Utilization_Ratio"], ax = ax[1], color= "grey")     
ax[1].set_title("Avg Utilization Ratio Distribution")  
sns.boxplot(x = df['Avg_Utilization_Ratio'], ax = ax[0],color='purple')
ax[0].set_title("Avg Utilization Ratio Boxplot")  
plt.show()

# %% [markdown]
# This is a right skewed data with no outliers.
# ## ***Interpretation: Around 75% of the customers are having low utilization (less than 0.5 utilization).

# %% [markdown]
# # $$\;\;\;\;\;\;Bivariate \ Analysis$$

# %% [markdown]
# ## CAT CAT Analysis: Categorical to Categorical

# %% [markdown]
# Level 2 Analysis (Getting closer to the BIG QUESTION: Churn Analysis)
# --------------------------------------------------------------------------------------------------
#
# How can this column make way to further analysis to answer the BIG QUESTION?
#
# What other columns could be clubbed with this Attrition Flag column to ask further questions?
#
# Below is the available list of columns/features in the given data.

# %%
categorical  # to check the names of the categorical columns
# Out:
# ['Attrition_Flag',
#  'Gender',
#  'Dependent_count',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category',
#  'Months_on_book',
#  'Total_Relationship_Count',
#  'Months_Inactive_12_mon',
#  'Contacts_Count_12_mon']

# %% [markdown]
# ## 15. Relationship of Attrition_Flag with Gender

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Gender", hue = "Attrition_Flag", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation: The percentage of women getting churned out is more than men.

# %% [markdown]
# ## 16. Relationship of Attrition_Flag with Dependent_count

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Dependent_count", hue = "Attrition_Flag", data = df,palette="mako")
plt.show()

# %% [markdown]
# ## ***Interpretation: Customers who are attrited or existing have a maximum of 2 to 3 dependents on them.

# %% [markdown]
# ## 17. Relationship of Attrition_Flag with Education_Level

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Education_Level", hue = "Attrition_Flag", data = df,palette='rocket')
plt.show()

# %% [markdown]
# ## ***Interpretation: Graduate and High School customers have a higher Attrition rate compared to other education level.

# %% [markdown]
# ## 18. Relationship of Attrition_Flag with Income_Category

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Income_Category", hue = "Attrition_Flag", data = df,palette='crest')
plt.show()

# %% [markdown]
# ## ***Interpretation: Almost 20-30% of customers who attrited are earning less than $40,000.

# %% [markdown]
# ## 19. Relationship of Attrition_Flag with Card_Category

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Card_Category", hue = "Attrition_Flag", data = df,palette="Paired")
plt.show()

# %% [markdown]
# ## ***Interpretation: The majority of the customers are churning from the blue card category. It is also to be noted that the maximum number of customers are also blue card holders.

# %% [markdown]
# ## CAT NUM ANALYSIS: Categorical to continuous

# %%
continuous  # to check the names of the continuous columns
# Out:
# ['CLIENTNUM',
#  'Customer_Age',
#  'Credit_Limit',
#  'Total_Revolving_Bal',
#  'Avg_Open_To_Buy',
#  'Total_Trans_Amt',
#  'Total_Trans_Ct',
#  'Avg_Utilization_Ratio']

# %% [markdown]
# CAT-NUM ANALYSIS (relationship between categorical and numerical data)
# -----------------------------------------------------------------------------------------------------------
#
# One could ask the following questions about the customers who have left the bank by relating
# attrition flag column, with each and every numerical column mentioned above
#
# 1. Customer age analysis of the customers who left the bank.
# 2. Credit limit analysis of the customers who have left the bank.
# 3. Average utilization ratio analysis of the customers who left the bank.
# 4. Analysis of Average Open to Buy and the churned-out customers.
# 5. Analysis of the Total Transaction Amount of the customers who have left the bank.
#
# Note: We could repeat the same analysis with customers who are still with the bank.
# 1. Customer age analysis of the customers who are with the bank.
# 2. Credit limit analysis of customers who are still with the bank.
# 3. Average utilization ratio analysis of the customers who are still with the bank.
# 4. Analysis of Average Open to Buy and existing customers.
# 5. Analysis of Total Transaction Amount with the customers who are still with the bank.
#
#
# A lot more analysis can be carried out this way!

# %% [markdown]
# ## 20. Relationship of Attrition_Flag with Customer_Age

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["Customer_Age"], hue = df["Attrition_Flag"], ax = ax[0])
sns.boxplot(y = df["Customer_Age"], x = df["Attrition_Flag"], ax = ax[1])
plt.show()

# %% [markdown]
# ## ***Interpretation: Most of the bank customers  are between 40 to 50 years of age.

# %% [markdown]
# ## 21. Relationship of Attrition_Flag with Credit_Limit

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["Credit_Limit"], hue = df["Attrition_Flag"], ax = ax[0])
sns.boxplot(x = df["Attrition_Flag"] ,y = df["Credit_Limit"] , ax = ax[1])
plt.show()

# %% [markdown]
# This is a right skewed data.
# ## ***Interpretation: There is not a significant difference in the credit limit of the existing customers and those who have left the bank. This paves the way for interesting analysis as to why customers choose to stay with the bank or leave.

# %% [markdown]
# ## 22. Relationship of Attrition_Flag with Avg_Utilization_Ratio

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["Avg_Utilization_Ratio"], hue = df["Attrition_Flag"], ax = ax[0])
sns.boxplot(x = df["Attrition_Flag"] ,y = df["Avg_Utilization_Ratio"] , ax = ax[1])
plt.show()

# %% [markdown]
# ## ***Interpretation: Customers who churned have very low usage. Most of them haven't used their cards. Around  75% of customers who churned have usage only of only 0.2%.

# %% [markdown]
# # Level 3 Further Analysis Questions

# %% [markdown]
# ## 1. Which age group of women has a larger churn?

# %%
df.iloc[140,:]
# Out:
# CLIENTNUM                           789322833
# Attrition_Flag              Attrited Customer
# Customer_Age                               48
# Gender                                      F
# Dependent_count                             5
# Education_Level                   High School
# Marital_Status                        Married
# Income_Category                Less than $40K
# Card_Category                            Blue
# Months_on_book                             38
# Total_Relationship_Count                    1
# Months_Inactive_12_mon                      3
# Contacts_Count_12_mon                       3
# Credit_Limit                           8025.0
# Total_Revolving_Bal                         0
# Avg_Open_To_Buy                        8025.0
# Total_Trans_Amt                           673
# Total_Trans_Ct                             18
# Avg_Utilization_Ratio                     0.0
# Name: 140, dtype: object

# %%
# Create age labels
females = df[(df["Gender"]=="F") & (df["Attrition_Flag"]=="Attrited Customer")] # accessing the data using conditional statements where & is a bitwise operator 
bins =     [0,30, 40,50, 60, 70]                                             # Create the bins
labels =  ["Young", "Adult", "Senior", "Super-Seinor", "old"]                   # setting the labels for the bins 
data = pd.cut(females["Customer_Age"], bins = bins, labels = labels)
data = data.value_counts()                                                      # value count is counting the number of values in the column
data
# Out:
# Senior          460
# Super-Seinor    262
# Adult           171
# old              29
# Young            17
# Name: Customer_Age, dtype: int64

# %%
pie, ax = plt.subplots(figsize = [10,6])
plt.pie(x = data,explode=[0.02,0.02,0.05,0.08,0.3],autopct="%0.2f%%",labels =data.index, pctdistance = 0.5, shadow=True, startangle=30) #autopct is used to present the percentage, explode is used to seprate the pie
                                                                                            # pctdistance is the distance betweeen the percentage numbers on the pie
plt.title("Female Age group Attrition")
plt.show()

# %% [markdown]
# ## ***Interpretation: Senior women have higher churn followed by Super-Senior.

# %% [markdown]
# ## 2. Analyze the churn of women customers based on their education levels.

# %%
data = df[(df["Gender"]=="F") & (df["Attrition_Flag"]=="Attrited Customer")]
data = data["Education_Level"] 
data = data.value_counts()
data
# Out:
# Graduate         296
# High School      175
# Unknown          152
# Uneducated       128
# College           79
# Doctorate         64
# Post-Graduate     45
# Name: Education_Level, dtype: int64

# %%
pie, ax = plt.subplots(figsize = [10,6])
plt.pie(x = data,labels =data.index, pctdistance = 0.5, autopct="%0.2f%%",shadow=True, startangle=30) #autopct is used to present the percentage, explode is used to seprate the pie
                                                                                            # pctdistance is the distance betweeen the percentage numbers on the pie
plt.title("Education level group Attrition")
plt.show()

# %% [markdown]
# ## ***Interpretation: Based on the education level, graduate females are churning out more compared to those who are post-graduate or doctorate.

# %% [markdown]
# ## 3. Do you think the average total transaction amount of women who churned out is different from those who are still with the bank?

# %%
with_bank = df[(df["Gender"] == "F") & (df["Attrition_Flag"] == "Existing Customer")]
left_bank = df[(df["Gender"] == "F") & (df["Attrition_Flag"] == "Attrited Customer")]
with_bank_mean = with_bank["Total_Trans_Amt"].mean()
left_bank_mean = left_bank["Total_Trans_Amt"].mean()
print(f"Women who are with the bank their average transaction amount is {round(with_bank_mean, 3)}")
print(f"Women who left the bank their average transaction amount is {round(left_bank_mean,3)}")
# Out:
# Women who are with the bank their average transaction amount is 4650.579
# Women who left the bank their average transaction amount is 2792.6

# %%
data = [4650, 2792]
fig, ax = plt.subplots(figsize = [10,6])
plt.pie(data, labels = ["Existing Customers", "Attired Customers"],explode=[0.02,0.03],pctdistance = 0.5, autopct="%0.2f%%",shadow=True, startangle=90)
plt.title("Difference of Transaction in women")
plt.show()

# %% [markdown]
# ## ***Interpretation: Yes, there is a difference in the transaction amount made by the women who are with the bank compared to the women who left the bank.

# %% [markdown]
# ## 4. Age-wise analysis of the customers whose dependent count is 2 or 3 (Existing and Churned out)

# %%
data = df[(df["Dependent_count"] == 2) | (df["Dependent_count"] == 3)]
g = sns.FacetGrid(data, col = "Dependent_count", height = 7)
g.map(sns.histplot, "Customer_Age")
plt.show()

# %% [markdown]
# ###  More information is required to make a conclusion.

# %%
# checking for the average of the dependent count 2 and 3
dep_2_mean = data[data["Dependent_count"] == 2]["Customer_Age"].mean()
dep_3_mean = data[data["Dependent_count"] == 3]["Customer_Age"].mean()
print(dep_2_mean)
print(dep_3_mean)
# Out:
# 46.30863282697295
# 45.492273730684325

# %%
data = [46.30, 45.49]
fig, ax = plt.subplots(figsize = [10,6])
plt.pie(data, labels = ["Dependent_count=2 ", " Dependent_count=3"],explode=[0.02,0.03],pctdistance = 0.5, autopct="%0.2f%%",shadow=True, startangle=90)
plt.title("Difference of dependents counts Age wise")
plt.show()

# %% [markdown]
# ## ***Interpretation: Most customers have the same age distribution based on their dependent counts.

# %% [markdown]
# ## 5. Is there any relation between the number of dependents (2 or 3) and the education level of customers who are existing and those who churned out?

# %%
data = df[(df["Dependent_count"] == 2) | (df["Dependent_count"] == 3)]
g = sns.FacetGrid(data, col ="Dependent_count", height = 7)
g.map(sns.countplot, "Education_Level")
plt.show()

# %% [markdown]
# ## ***Interpretation: The customers who have 2 dependents are usually high school and college pass-outs, but those who have 3 dependents are graduates and high school pass-outs.

# %% [markdown]
# ## 6. Do you think the column "Average open to buy" is affected by the dependent count (2 or 3)?

# %%
data = df[(df["Dependent_count"] == 2) | (df["Dependent_count"] == 3)]
g = sns.FacetGrid(data, col = "Dependent_count", height = 7)
g.map(sns.histplot, "Avg_Open_To_Buy")
plt.show()

# %% [markdown]
# ####  More information is required to make a conclusion.

# %%
# checking for the average of the dependent count 2 and 3
dep_2_median = data[data["Dependent_count"] == 2]["Avg_Open_To_Buy"].median()
dep_3_median = data[data["Dependent_count"] == 3]["Avg_Open_To_Buy"].median()
print(dep_2_median)
print(dep_3_median)
# Out:
# 3557.0
# 3830.5

# %%
data = [3557, 3830]
fig, ax = plt.subplots(figsize = [10,6])
plt.pie(data, labels = ["2 Dependents", "3 Dependents"],explode=[0.02,0.03],pctdistance = 0.5, autopct="%0.2f%%",shadow=True, startangle=90)
plt.title("Difference of dependents")
plt.show()

# %% [markdown]
# ## ***Interpretation: Most customers have the same Average open-to-buy distribution based on their dependents.

# %% [markdown]
# ## 7. Card category wise analysis of customers who are high school pass outs and churned out

# %%
data_df = df[(df["Education_Level"] == "High School") | (df["Attrition_Flag"] == "Attrited Customer")]
print("There are "+str(len(data_df))+" number of customers who are high school pass outs and churned out.")
# Out:
# There are 3334 number of customers who are high school pass outs and churned out.

# %%
card_mode = data_df.Card_Category.mode()[0]
print(card_mode)
data_df["Card_Category"].fillna(card_mode, inplace = True)
# Out:
# Blue

# %%
data = data_df["Card_Category"].value_counts()                                   #value count is counting the number of values in the column
print(data)
pie, ax = plt.subplots(1, 2, figsize = [20,6])
labels =data.keys()                                                         # Keys returning you the index names in the data
ax[0].pie(x = data, explode = [0.2, 0.2, 0.45, 0.67], labels = labels)         # pctdistance is the distance between the percentage on pie chart from center.
                                                                                #  explode is to split the slices by the distance provided
sns.countplot(x = data_df["Card_Category"], ax = ax[1], order = data_df["Card_Category"].value_counts().index)                                                                                               
plt.title("Card_Category")                                                  # title is used to prints the title on the image. 
plt.show()
# Out:
# Blue        3123
# Silver       162
# Gold          43
# Platinum       6
# Name: Card_Category, dtype: int64

# %% [markdown]
# ## ***Interpretation: The majority of the population uses the Blue card followed by Silver. The Platinum card is sold the least.

# %% [markdown]
# ## 8. Income category wise breakdown of the customers who are high school pass outs and are still with the bank

# %%
data_df = df[(df["Education_Level"] == "High School") | (df["Attrition_Flag"] == "Existing Customer")]
print("There are "+str(len(data_df))+" number of customers who are high school pass outs and still with the bank.")
# Out:
# There are 8806 number of customers who are high school pass outs and still with the bank.

# %%
card_mode = data_df.Card_Category.mode()[0]
print(card_mode)
data_df["Card_Category"].fillna(card_mode, inplace = True)
# Out:
# Blue

# %%
data = data_df["Card_Category"].value_counts()                                   #value count is counting the number of values in the column
print(data)
pie, ax = plt.subplots(1, 2, figsize = [20,6])
labels =data.keys()                                                         # Keys returning you the index names in the data
ax[0].pie(x = data, explode = [0.2, 0.2, 0.45, 0.67], labels = labels)         # pctdistance is the distance between the percentage on pie chart from center.
                                                                                #  explode is to split the slices by the distance provided
sns.countplot(x = data_df["Card_Category"], ax = ax[1], order = data_df["Card_Category"].value_counts().index)                                                                                               
plt.title("Card_Category")                                                  # title is used to prints the title on the image. 
plt.show()
# Out:
# Blue        8213
# Silver       479
# Gold          99
# Platinum      15
# Name: Card_Category, dtype: int64

# %% [markdown]
# ## ***Interpretation: The majority of the population uses the Blue card followed by Silver. The Platinum card is sold the least.

# %% [markdown]
# ## 9. Present the details of Total Transaction Amount of existing customers who are high school pass outs

# %%
filtered_df = df[(df.Attrition_Flag == 'Existing Customer')]
total_transaction = filtered_df.groupby(["Education_Level" ])["Total_Trans_Amt"].count()
total_transaction
# Out:
# Education_Level
# College           859
# Doctorate         356
# Graduate         2641
# High School      1707
# Post-Graduate     424
# Uneducated       1250
# Unknown          1263
# Name: Total_Trans_Amt, dtype: int64

# %%
cust_total_transaction = total_transaction.index
cust_edu = total_transaction.values

plt.figure(figsize = (10,5))

sns.barplot(cust_total_transaction, cust_edu)
plt.title("Total Transaction Ammount")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## ***Interpretation: Total transaction Amount of existing customers who are high school pass outs is 1707.

# %% [markdown]
# ## 10. Analysis of the education level of the customers who are with the bank and those who left

# %%
stayed = df[df['Attrition_Flag'] == "Existing Customer"]
left = df[df['Attrition_Flag'] == "Attrited Customer"]
stayed_edu = stayed['Education_Level'].value_counts()
left_edu = left['Education_Level'].value_counts()
print(stayed_edu)
print()
print(left_edu)
# Out:
# Graduate         2641
# High School      1707
# Unknown          1263
# Uneducated       1250
# College           859
# Post-Graduate     424
# Doctorate         356
# Name: Education_Level, dtype: int64
#
# Graduate         487
# High School      306
# Unknown          256
# Uneducated       237
# College          154
# Doctorate         95
# Post-Graduate     92
# Name: Education_Level, dtype: int64

# %%
stayed = df[df['Attrition_Flag'] == "Existing Customer"]
left = df[df['Attrition_Flag'] == "Attrited Customer"]

stayed_edu = stayed['Education_Level'].value_counts()
left_edu = left['Education_Level'].value_counts()

plt.figure(figsize=(9,5))
plt.bar(stayed_edu.index, stayed_edu.values, alpha=0.5, label='Stayed')
plt.bar(left_edu.index, left_edu.values, alpha=0.5, label='Left')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.title('Education Level of Customer Who Stayed vs. Left')
plt.show()

# %% [markdown]
# ## Interpretation: It is seen that attrition rate is highere in high school total 306 customers out of 1707.

# %% [markdown]
# ## 11. Analysis of Transaction Amount (mean, median, and mode) made by the existing customers and comparing it with those who are not existing

# %%
stayed_cust = df[df['Attrition_Flag'] == "Existing Customer"]
left_cust = df[df['Attrition_Flag'] == "Attrited Customer"]

stayed_Mean = stayed_cust["Total_Trans_Amt"].mean()
stayed_Mode = stayed_cust["Total_Trans_Amt"].mode()[0]
stayed_Median = stayed_cust["Total_Trans_Amt"].median()

left_Mean = left_cust["Total_Trans_Amt"].mean()
left_Mode = left_cust["Total_Trans_Amt"].mode()[0]
left_Median = left_cust["Total_Trans_Amt"].median()



data = {
    'Statistics': ['Mean', 'Mode', 'Median'],
    'Existing Customer': [stayed_Mean, stayed_Mode, stayed_Median],
    'Attrited Customer': [left_Mean, left_Mode, left_Median]
}

cust = pd.DataFrame(data)
cust
# Out:
#   Statistics  Existing Customer  Attrited Customer
# 0       Mean        4654.655882        3095.025814
# 1       Mode        4253.000000        2108.000000
# 2     Median        4100.000000        2329.000000

# %%
# Set the style of the plot
plt.style.use('ggplot')

# Plotting the graph
cust.plot(x='Statistics', y=['Existing Customer', 'Attrited Customer'], kind='bar')

# Adding labels and title
plt.xlabel('Statistics')
plt.ylabel('Total Transaction Amount')
plt.title('Comparison of Total Transaction Amount for Existing vs. Attrited Customers')

# Displaying the graph
plt.show()

# %% [markdown]
# ## 12. What is the average utilization ratio of the existing customers?

# %%
stayed_Mean = df[df['Attrition_Flag'] == "Existing Customer"]["Avg_Utilization_Ratio"].mean()
left_Mean = df[df['Attrition_Flag'] == "Attrited Customer"]["Avg_Utilization_Ratio"].mean()

print(f"Average utilization ratio of existing customers is {round(stayed_Mean, 3)}")
print(f"Average utilization ratio of attrited customers is {round(left_Mean, 3)}")
# Out:
# Average utilization ratio of existing customers is 0.296
# Average utilization ratio of attrited customers is 0.162

# %%
# Create a pie plot
labels = ['Existing Customer', 'Attrited Customer']
sizes = [stayed_Mean, left_Mean]
colors = sns.color_palette('hls', n_colors=len(labels))
plt.pie(sizes, labels=labels,colors=colors,  autopct="%0.2f%%", explode=[0.02]*len(labels), shadow=True, startangle=90)

# Add title
plt.title('Comparison of Average Utilization Ratio\nfor Existing vs. Attrited Customers')

# Display the plot
plt.show()

# %% [markdown]
# ## ***Interpretation: Average utilization ratio of existing xustomer is 0.296.

# %% [markdown]
# ## 13. Analysis of the churned out customers who hold the blue card with respect to their income categories

# %%
left = df[(df['Attrition_Flag'] == "Attrited Customer")| (df['Card_Category'] == "Blue")]
fig, ax = plt.subplots(figsize= (8, 5))
ax = sns.countplot(x = left["Income_Category"])
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40 , ha = "right")
count = len(df["Income_Category"])                                     
for bar in ax.patches:                                                 
    percentage = f"{round(bar.get_height()/count, 2)*100} %"           
                                                                            
    x = bar.get_x() + bar.get_width() /2                                
    y = bar.get_height()                                                
    ax.annotate(percentage, (x, y), ha = "center", va = "top")          
                                                                        
plt.show()

# %% [markdown]
# ## ***Interpretation: Most of the customers left the card whose income is less than  $ 40000.

# %% [markdown]
# ## 14. Analysis of transaction amount (mean, median, mode) for blue card customers who are no longer with the bank and comparing it with the existing customers

# %%
# Filter the data for blue card customers
blue_customers = df[df["Card_Category"] == "Blue"]

# Separate churned and existing blue card customers
churned_customers = blue_customers[blue_customers["Attrition_Flag"] == "Attrited Customer"]
existing_customers = blue_customers[blue_customers["Attrition_Flag"] == "Existing Customer"]

# Calculate transaction amount statistics for churned customers
churned_mean = churned_customers["Total_Trans_Amt"].mean()
churned_median = churned_customers["Total_Trans_Amt"].median()
churned_mode = churned_customers["Total_Trans_Amt"].mode()[0]

# Calculate transaction amount statistics for existing customers
existing_mean = existing_customers["Total_Trans_Amt"].mean()
existing_median = existing_customers["Total_Trans_Amt"].median()
existing_mode = existing_customers["Total_Trans_Amt"].mode()[0]

# Print the results
print("Transaction Amount Statistics for Blue Card Customers:")
print("Churned Customers:")
print("Mean: {:.2f}".format(churned_mean))
print("Median: {:.2f}".format(churned_median))
print("Mode: {:.2f}".format(churned_mode))
print()
print("Existing Customers:")
print("Mean: {:.2f}".format(existing_mean))
print("Median: {:.2f}".format(existing_median))
print("Mode: {:.2f}".format(existing_mode))
# Out:
# Transaction Amount Statistics for Blue Card Customers:
# Churned Customers:
# Mean: 2957.84
# Median: 2314.00
# Mode: 2108.00
#
# Existing Customers:
# Mean: 4468.25
# Median: 4085.00
# Mode: 4253.00

# %%
# Plotting the graph
labels = ['Mean', 'Median', 'Mode']
churned_values = [churned_mean, churned_median, churned_mode]
existing_values = [existing_mean, existing_median, existing_mode]

x = range(len(labels))

plt.bar(x, churned_values, width=0.4, label='Churned Customers')
plt.bar(x, existing_values, width=0.4, label='Existing Customers', alpha=0.5)

plt.xlabel('Transaction Amount Statistics')
plt.ylabel('Transaction Amount')
plt.title('Comparison of Transaction Amount Statistics\nfor Churned vs. Existing Blue Card Customers')
plt.xticks(x, labels)
plt.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 15. How is the credit limit of the blue card customers affecting the churn?

# %%
# Filter the data for blue card customers
blue_customers = df[df["Card_Category"] == "Blue"]

# Calculate churn rate for blue card customers
total_customers = len(blue_customers)
churned_customers = len(blue_customers[blue_customers["Attrition_Flag"] == "Attrited Customer"])
churn_rate = churned_customers / total_customers

# Print the churn rate
print("Churn rate for blue card customers: {:.2%}".format(churn_rate))

# Analyze how credit limit affects the churn rate
credit_limit_bins = pd.cut(blue_customers["Credit_Limit"], bins=10)
churn_rates_by_credit_limit = blue_customers.groupby(credit_limit_bins)["Attrition_Flag"].apply(lambda x: len(x[x == "Attrited Customer"]) / len(x)).fillna(0)

# Visualize the results using a line chart
plt.figure(figsize=(12, 6))
ax = churn_rates_by_credit_limit.plot.line()
ax.set_xlabel("Credit Limit")
ax.set_ylabel("Churn Rate")
ax.set_title("Churn Rate vs. Credit Limit for Blue Card Customers")
plt.show()
# Out:
# Churn rate for blue card customers: 16.10%

# %% [markdown]
# ## ***Interpretation: It is seen that the churn rate is higher where the credit limit is less than 5000 dollars. but as it is a negative correlation till approx 20000 dollars we can conclude as credit limit increases customers are less likely to churn. However, after 20000 dollars, it is a positive correlation, which means that customers with higher credit limits are more likely to churn. Maybe another reason is there for the churn rate.

# %% [markdown]
# ## 16. Analysis of the dependent count with respect to the customers who have churned out and the customers who are still using the services

# %%
#Separate the data for churned customers and existing customers:

churned_customers = df[df['Attrition_Flag'] == 'Attrited Customer']
existing_customers = df[df['Attrition_Flag'] == 'Existing Customer']

#Calculate the average dependent count for churned customers and existing customers:

churned_avg_dependents = churned_customers['Dependent_count'].mean()
existing_avg_dependents = existing_customers['Dependent_count'].mean()

print(f"Average dependent count for churned customers: {churned_avg_dependents:.2f}")
print(f"Average dependent count for existing customers: {existing_avg_dependents:.2f}")
# Out:
# Average dependent count for churned customers: 2.40
# Average dependent count for existing customers: 2.33

# %%
# Create a pie plot
labels = ['Churned Customers', 'Existing Customers']
sizes = [churned_avg_dependents, existing_avg_dependents]

plt.pie(sizes, labels=labels, autopct='%0.2f%%',explode=[0.02]*len(labels), shadow=True, startangle=90)

# Add title
plt.title('Comparison of Average Dependent Count\nfor Churned vs. Existing Customers')

# Display the plot
plt.show()

# %% [markdown]
# ## ***Interpretation: The average dependent count for churned customers is 50%.

# %% [markdown]
# ## 17. Is there a relation between the credit limit and the attrition of the customers?

# %%
churned_customers = df[df['Attrition_Flag'] == 'Attrited Customer']
existing_customers = df[df['Attrition_Flag'] == 'Existing Customer']

plt.figure(figsize=(8, 6))
sns.boxplot(x='Attrition_Flag', y='Credit_Limit', data=df)
plt.xlabel('Customer Attrition')
plt.ylabel('Credit Limit')
plt.title('Credit Limit Distribution for Churned and Existing Customers')
plt.show()

# %%
#Perform a statistical test, such as an independent t-test, to determine if there is a significant difference in credit limit between churned and existing customers:
from scipy.stats import ttest_ind

# Perform independent t-test
t_stat, p_value = ttest_ind(churned_customers['Credit_Limit'], existing_customers['Credit_Limit'])

# Print the p-value
print('P-value:', p_value)
# Out:
# P-value: nan

# %% [markdown]
# ## 18. What is the average utilization ratio of the credit card for each age sub-group between 40 and 50? (We need to group the customers into 4 buckets between 40 and 50.)

# %%
#define age buckets
age_bins = pd.cut(df['Customer_Age'], bins=[40, 43, 46, 49, 52])

#Filter the data for customers between the ages of 40 and 50
filtered_data = df[(df['Customer_Age'] >= 40) & (df['Customer_Age'] <= 50)]

#Calculate the average utilization ratio for each age sub-group
avg_utilization_ratio = filtered_data.groupby(age_bins)['Avg_Utilization_Ratio'].mean()

# Plotting the graph
avg_utilization_ratio.plot(kind='bar')
plt.xlabel('Age Sub-Group')
plt.ylabel('Average Utilization Ratio')
plt.title('Average Utilization Ratio of Credit Card\nfor Each Age Sub-Group (40-50)')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(data=df.corr(), annot=True, fmt='.1g')
# Out:
# <AxesSubplot:>
